# %%
import pandas as pd
import matplotlib.pyplot as plt

df_movies = pd.read_csv(r"C:\Users\dell_14\Desktop\TAREA ROTEN\Rotten_Tomates\Rotten Tomatoes Movies.csv")

status_counts = df_movies['tomatometer_status'].value_counts()
print(status_counts)

status_counts.plot.pie(autopct='%1.1f%%', figsize=(6,6))
plt.title("Distribución de clasificacion por la critica")
plt.ylabel("")
plt.show()
# Out:
# tomatometer_status
# Rotten             7233
# Fresh              6448
# Certified Fresh    2957
# Name: count, dtype: int64
